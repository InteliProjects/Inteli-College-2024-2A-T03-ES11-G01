# %%
import pandas as pd

df = pd.read_csv('sku_dataset.csv', delimiter=';')

# %%
df.head()
# Out:
#        cod_prod                       nome_abrev  \
# 0  603078352615     Acne Solutions Cleansing Bar
# 1  131384024501               Pep Start Daily UV
# 2   85873708529           Deep Comfort Body Wash
# 3  579926605113      Lipikar Wash Gentle Foaming
# 4  397769055946  Anthelios AOX Daily Antioxidant
#
#                                        nome_completo  \
# 0       Acne Solutions Cleansing Bar for Face & Body
# 1  Pep Start Daily UV Protector Broad Spectrum SP...
# 2                             Deep Comfort Body Wash
# 3  Lipikar Wash AP+ Gentle Foaming Moisturizing Wash
# 4  Anthelios AOX Daily Antioxidant Face Serum SPF 50
#
#                                            descricao categoria  \
# 0  Sabonete líquido Clinique Acne Solutions Clean...     Corpo
# 1  Protetor solar Clinique Pep Start Daily UV Pro...     Corpo
# 2  Sabonete líquido Clinique Deep Comfort Body Wa...     Corpo
# 3  Sabonete líquido La Roche-Posay Lipikar Wash A...     Corpo
# ...
